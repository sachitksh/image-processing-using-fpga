# %%
import numpy as np
import cv2
from PIL import Image as im
import matplotlib.pyplot as plt

# %%
image = cv2.imread("gray.bmp")

# %%
np.shape(image)
# Out:
# (400, 300, 3)

# %%
a = np.array(image)

# %%
b=np.array([[0,-1,0],[-1,5,-1],[0,-1,0]])

# %%
z = np.zeros((np.shape(a)[0]-2,np.shape(a)[1]-2))

# %%
for i in range(np.shape(a)[0]-2):
    for j in range(np.shape(a)[1]-2):
        if(i<np.shape(a)[0]-2 and j<np.shape(a)[1]-2):
            z[i][j]=int((np.multiply(a[i:i+3,[j,j+1,j+2]],b)).sum())

# %%
z.shape
# Out:
# (398, 298)

# %%
data = im.fromarray(z)

# %%
cv2.imwrite('sharpen2.jpg', z)
# Out:
# True

# %%
z
# Out:
# array([[461., 476., 471., ..., 508., 494., 474.],
#        [471., 467., 472., ..., 506., 498., 480.],
#        [478., 471., 476., ..., 502., 502., 491.],
#        ...,
#        [247., 129.,  -1., ..., 471., 464., 502.],
#        [238.,  67.,   1., ..., 421., 490., 531.],
#        [194.,  55.,   5., ..., 428., 459., 484.]])

# %%
cv2.imwrite('test.jpg', image)
# Out:
# True

# %%
_, ax = plt.subplots(1, 2, figsize=(12, 6))
ax[0].imshow(image, cmap='gray')
ax[1].imshow(z, cmap='gray');

# %%
def negative_to_zero(img: np.array) -> np.array:
    img = img.copy()
    img[img < 0] = 0
    return img

# %%
_, ax = plt.subplots(1, 2, figsize=(12, 6))
ax[0].imshow(image, cmap='gray')
ax[1].imshow(negative_to_zero(z), cmap='gray');

# %%
cv2.imwrite('sharpen3.jpg', negative_to_zero(z),)
# Out:
# True

# %%
img_with_padding_3x3 = add_padding_to_image(
    img=np.array(img), 
    padding_width=pad_3x3
)
